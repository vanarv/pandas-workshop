# %% [markdown]
# # Checking your setup
# Run through this notebook to make sure your environment is properly setup. Be sure to launch Jupyter from inside the virtual environment.

# %%
from utils import run_env_check
run_env_check()

# %% [markdown]
# *Note: Adapted from Andreas Mueller's [`check_env.ipynb` notebook](https://github.com/amueller/ml-workshop-1-of-4/blob/master/check_env.ipynb).*

# %%
import sys
# !{sys.executable} -m pip install jupyterlab
# Out:
# Looking in indexes: https://artifacts.co.clearstreet.io/artifactory/api/pypi/python/simple, https://pypi.org/simple
# Collecting jupyterlab
#   Downloading jupyterlab-3.5.2-py3-none-any.whl (8.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 10.5 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: jinja2>=2.1 in /opt/homebrew/lib/python3.10/site-packages (from jupyterlab) (3.1.2)
# Collecting jupyterlab-server~=2.10
#   Downloading jupyterlab_server-2.18.0-py3-none-any.whl (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.4/56.4 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: notebook<7 in /opt/homebrew/lib/python3.10/site-packages (from jupyterlab) (6.4.12)
# Requirement already satisfied: jupyter-core in /opt/homebrew/lib/python3.10/site-packages (from jupyterlab) (4.11.1)
# Collecting jupyter-server<3,>=1.16.0
#   Downloading jupyter_server-2.1.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.2/365.2 kB 6.1 MB/s eta 0:00:000:00:01
# Collecting nbclassic
#   Downloading nbclassic-0.4.8-py3-none-any.whl (9.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.8/9.8 MB 7.1 MB/s eta 0:00:00m eta 0:00:010:00:01m
# Requirement already satisfied: ipython in /opt/homebrew/lib/python3.10/site-packages (from jupyterlab) (8.5.0)
# Requirement already satisfied: tornado>=6.1.0 in /opt/homebrew/lib/python3.10/site-packages (from jupyterlab) (6.2)
# Collecting tomli
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in /opt/homebrew/lib/python3.10/site-packages (from jupyterlab) (21.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/homebrew/lib/python3.10/site-packages (from jinja2>=2.1->jupyterlab) (2.1.1)
# Collecting websocket-client
#   Downloading websocket_client-1.4.2-py3-none-any.whl (55 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 1.9 MB/s eta 0:00:00
# Collecting jupyter-core
#   Downloading jupyter_core-5.1.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.5/93.5 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: prometheus-client in /opt/homebrew/lib/python3.10/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.14.1)
# Collecting pyzmq>=24
#   Downloading pyzmq-25.0.0-cp310-cp310-macosx_10_15_universal2.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 6.1 MB/s eta 0:00:000:00:01m eta 0:00:01
# Requirement already satisfied: terminado>=0.8.3 in /opt/homebrew/lib/python3.10/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (0.15.0)
# Collecting traitlets>=5.6.0
#   Downloading traitlets-5.8.1-py3-none-any.whl (116 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.8/116.8 kB 2.9 MB/s eta 0:00:00
# Collecting jupyter-client>=7.4.4
#   Downloading jupyter_client-7.4.9-py3-none-any.whl (133 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.5/133.5 kB 3.1 MB/s eta 0:00:00m eta 0:00:01
# Requirement already satisfied: send2trash in /opt/homebrew/lib/python3.10/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (1.8.0)
# Collecting jupyter-server-terminals
#   Downloading jupyter_server_terminals-0.4.4-py3-none-any.whl (13 kB)
# Collecting anyio<4,>=3.1.0
#   Downloading anyio-3.6.2-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: nbformat>=5.3.0 in /opt/homebrew/lib/python3.10/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (5.4.0)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/homebrew/lib/python3.10/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (7.0.0)
# Requirement already satisfied: argon2-cffi in /opt/homebrew/lib/python3.10/site-packages (from jupyter-server<3,>=1.16.0->jupyterlab) (21.3.0)
# Collecting jupyter-events>=0.4.0
#   Downloading jupyter_events-0.6.3-py3-none-any.whl (18 kB)
# Requirement already satisfied: platformdirs>=2.5 in /opt/homebrew/lib/python3.10/site-packages (from jupyter-core->jupyterlab) (2.5.2)
# Collecting babel>=2.10
#   Downloading Babel-2.11.0-py3-none-any.whl (9.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 5.7 MB/s eta 0:00:00m eta 0:00:010:01:01
# Collecting json5>=0.9.0
#   Downloading json5-0.9.11-py2.py3-none-any.whl (19 kB)
# Collecting jsonschema>=4.17.3
#   Downloading jsonschema-4.17.3-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.4/90.4 kB 1.6 MB/s eta 0:00:005 MB/s eta 0:00:01
# Requirement already satisfied: requests>=2.28 in /opt/homebrew/lib/python3.10/site-packages (from jupyterlab-server~=2.10->jupyterlab) (2.28.1)
# Requirement already satisfied: ipykernel in /opt/homebrew/lib/python3.10/site-packages (from notebook<7->jupyterlab) (6.15.2)
# Requirement already satisfied: nest-asyncio>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from notebook<7->jupyterlab) (1.5.5)
# Requirement already satisfied: ipython-genutils in /opt/homebrew/lib/python3.10/site-packages (from notebook<7->jupyterlab) (0.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/homebrew/lib/python3.10/site-packages (from packaging->jupyterlab) (3.0.9)
# Requirement already satisfied: pygments>=2.4.0 in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (2.13.0)
# Requirement already satisfied: backcall in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (0.2.0)
# Requirement already satisfied: pickleshare in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (0.7.5)
# Requirement already satisfied: decorator in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (0.1.6)
# Requirement already satisfied: stack-data in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (0.5.0)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (3.0.31)
# Requirement already satisfied: appnope in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (0.1.3)
# Requirement already satisfied: jedi>=0.16 in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (0.18.1)
# Requirement already satisfied: pexpect>4.3 in /opt/homebrew/lib/python3.10/site-packages (from ipython->jupyterlab) (4.8.0)
# Collecting notebook-shim>=0.1.0
#   Downloading notebook_shim-0.2.2-py3-none-any.whl (13 kB)
# Collecting sniffio>=1.1
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: idna>=2.8 in /opt/homebrew/lib/python3.10/site-packages (from anyio<4,>=3.1.0->jupyter-server<3,>=1.16.0->jupyterlab) (3.3)
# Requirement already satisfied: pytz>=2015.7 in /opt/homebrew/lib/python3.10/site-packages (from babel>=2.10->jupyterlab-server~=2.10->jupyterlab) (2022.2.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /opt/homebrew/lib/python3.10/site-packages (from jedi>=0.16->ipython->jupyterlab) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /opt/homebrew/lib/python3.10/site-packages (from jsonschema>=4.17.3->jupyterlab-server~=2.10->jupyterlab) (22.1.0)
# Requirement already satisfied: entrypoints in /opt/homebrew/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/homebrew/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.8.2)
# Collecting python-json-logger>=2.0.4
#   Downloading python_json_logger-2.0.4-py3-none-any.whl (7.8 kB)
# Requirement already satisfied: jsonschema[format-nongpl]>=3.2.0 in /opt/homebrew/lib/python3.10/site-packages (from jupyter-events>=0.4.0->jupyter-server<3,>=1.16.0->jupyterlab) (4.15.0)
# Collecting pyyaml>=5.3
#   Downloading PyYAML-6.0-cp310-cp310-macosx_11_0_arm64.whl (173 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.0/174.0 kB 3.8 MB/s eta 0:00:007.1 MB/s eta 0:00:01
# Collecting rfc3986-validator>=0.1.1
#   Downloading rfc3986_validator-0.1.1-py2.py3-none-any.whl (4.2 kB)
# Collecting rfc3339-validator
#   Downloading rfc3339_validator-0.1.4-py2.py3-none-any.whl (3.5 kB)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.6.7)
# Requirement already satisfied: tinycss2 in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.1.1)
# Requirement already satisfied: lxml in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.9.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.5.0)
# Requirement already satisfied: beautifulsoup4 in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (4.11.1)
# Requirement already satisfied: mistune<3,>=2.0.3 in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.0.4)
# Requirement already satisfied: bleach in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (5.0.1)
# Requirement already satisfied: defusedxml in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/homebrew/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.2.2)
# Requirement already satisfied: fastjsonschema in /opt/homebrew/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=1.16.0->jupyterlab) (2.16.1)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/homebrew/lib/python3.10/site-packages (from pexpect>4.3->ipython->jupyterlab) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/homebrew/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->jupyterlab) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server~=2.10->jupyterlab) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server~=2.10->jupyterlab) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.10/site-packages (from requests>=2.28->jupyterlab-server~=2.10->jupyterlab) (2022.6.15)
# Requirement already satisfied: argon2-cffi-bindings in /opt/homebrew/lib/python3.10/site-packages (from argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (21.2.0)
# Requirement already satisfied: psutil in /opt/homebrew/lib/python3.10/site-packages (from ipykernel->notebook<7->jupyterlab) (5.9.2)
# Requirement already satisfied: debugpy>=1.0 in /opt/homebrew/lib/python3.10/site-packages (from ipykernel->notebook<7->jupyterlab) (1.6.3)
# Requirement already satisfied: pure-eval in /opt/homebrew/lib/python3.10/site-packages (from stack-data->ipython->jupyterlab) (0.2.2)
# Requirement already satisfied: asttokens in /opt/homebrew/lib/python3.10/site-packages (from stack-data->ipython->jupyterlab) (2.0.8)
# Requirement already satisfied: executing in /opt/homebrew/lib/python3.10/site-packages (from stack-data->ipython->jupyterlab) (1.0.0)
# Collecting isoduration
#   Downloading isoduration-20.11.0-py3-none-any.whl (11 kB)
# Collecting fqdn
#   Downloading fqdn-1.5.1-py3-none-any.whl (9.1 kB)
# Collecting uri-template
#   Downloading uri_template-1.2.0-py3-none-any.whl (10 kB)
# Collecting jsonpointer>1.13
#   Downloading jsonpointer-2.3-py2.py3-none-any.whl (7.8 kB)
# Collecting webcolors>=1.11
#   Downloading webcolors-1.12-py3-none-any.whl (9.9 kB)
# Requirement already satisfied: six>=1.5 in /opt/homebrew/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter-client>=7.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (1.16.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/homebrew/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/homebrew/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (2.3.2.post1)
# Requirement already satisfied: webencodings in /opt/homebrew/lib/python3.10/site-packages (from bleach->nbconvert>=6.4.4->jupyter-server<3,>=1.16.0->jupyterlab) (0.5.1)
# Requirement already satisfied: pycparser in /opt/homebrew/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->jupyter-server<3,>=1.16.0->jupyterlab) (2.21)
# Collecting arrow>=0.15.0
#   Downloading arrow-1.2.3-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 5.8 MB/s eta 0:00:00
# Installing collected packages: json5, websocket-client, webcolors, uri-template, traitlets, tomli, sniffio, rfc3986-validator, rfc3339-validator, pyzmq, pyyaml, python-json-logger, jsonschema, jsonpointer, fqdn, babel, jupyter-server-terminals, jupyter-core, arrow, anyio, jupyter-client, isoduration, jupyter-events, jupyter-server, notebook-shim, jupyterlab-server, nbclassic, jupyterlab
#   Attempting uninstall: traitlets
#     Found existing installation: traitlets 5.3.0
#     Uninstalling traitlets-5.3.0:
#       Successfully uninstalled traitlets-5.3.0
#   Attempting uninstall: pyzmq
#     Found existing installation: pyzmq 23.2.1
#     Uninstalling pyzmq-23.2.1:
#       Successfully uninstalled pyzmq-23.2.1
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.15.0
#     Uninstalling jsonschema-4.15.0:
#       Successfully uninstalled jsonschema-4.15.0
#   Attempting uninstall: jupyter-core
#     Found existing installation: jupyter-core 4.11.1
#     Uninstalling jupyter-core-4.11.1:
#       Successfully uninstalled jupyter-core-4.11.1
#   Attempting uninstall: jupyter-client
#     Found existing installation: jupyter_client 7.3.5
#     Uninstalling jupyter_client-7.3.5:
#       Successfully uninstalled jupyter_client-7.3.5
# Successfully installed anyio-3.6.2 arrow-1.2.3 babel-2.11.0 fqdn-1.5.1 isoduration-20.11.0 json5-0.9.11 jsonpointer-2.3 jsonschema-4.17.3 jupyter-client-7.4.9 jupyter-core-5.1.3 jupyter-events-0.6.3 jupyter-server-2.1.0 jupyter-server-terminals-0.4.4 jupyterlab-3.5.2 jupyterlab-server-2.18.0 nbclassic-0.4.8 notebook-shim-0.2.2 python-json-logger-2.0.4 pyyaml-6.0 pyzmq-25.0.0 rfc3339-validator-0.1.4 rfc3986-validator-0.1.1 sniffio-1.3.0 tomli-2.0.1 traitlets-5.8.1 uri-template-1.2.0 webcolors-1.12 websocket-client-1.4.2
